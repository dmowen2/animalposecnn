# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.utils import to_categorical
import pickle
from sklearn.model_selection import train_test_split

X = pickle.load(open("UNX.pickle", "rb"))
Y = pickle.load(open("UNY.pickle", "rb"))

X = X/255.0


Y = to_categorical(Y, 3)

# First convolutional layer

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)


traintimes = 2
while traintimes > 0:
    print("Train Iteration: " + str(traintimes))
    model=Sequential()
    model.add(Conv2D(255, (3,3), input_shape = X.shape[1:]))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    # 256
    
    # 128
    # Second convolutional layer
    model.add(Conv2D(64, (3,3)))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))

    # 64
    # Third convolutional layer
    model.add(Conv2D(128, (3,3)))
    model.add(Activation("relu"))
    model.add(BatchNormalization()) # adding the batch normalization here significantly improved the accuracy of the model
    model.add(MaxPooling2D(pool_size=(2,2)))

    # added this
    model.add(Conv2D(64, (3,3)))
    model.add(Activation("relu"))
    model.add(BatchNormalization()) # adding the batch normalization here significantly improved the accuracy of the model
    model.add(MaxPooling2D(pool_size=(2,2)))
    
        # 64
    # fourth convolutional layer
    model.add(Conv2D(128, (3,3)))
    model.add(Activation("relu"))
    model.add(BatchNormalization()) # adding the batch normalization here significantly improved the accuracy of the model
    model.add(MaxPooling2D(pool_size=(2,2)))
    
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(64))
    model.add(Dense(32))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics="accuracy")


    model.fit(X_train, y_train, batch_size=32, epochs=10, validation_data=(X_test, y_test))

# change to 15

    _, train_acc = model.evaluate(X_train, y_train, verbose=0)
    _, test_acc = model.evaluate(X_test, y_test, verbose=0)

    print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
    traintimes -= 1
# Out:
# Train Iteration: 2
# Epoch 1/10
# 6/6 [==============================] - 35s 6s/step - loss: 5.1197 - accuracy: 0.5198 - val_loss: 1.1213 - val_accuracy: 0.3778
# Epoch 2/10
# 6/6 [==============================] - 34s 6s/step - loss: 1.5711 - accuracy: 0.7458 - val_loss: 3.5088 - val_accuracy: 0.3778
# Epoch 3/10
# 6/6 [==============================] - 33s 6s/step - loss: 0.6683 - accuracy: 0.8588 - val_loss: 5.8754 - val_accuracy: 0.3778
# Epoch 4/10
# 6/6 [==============================] - 33s 6s/step - loss: 0.2602 - accuracy: 0.9266 - val_loss: 6.2396 - val_accuracy: 0.3778
# Epoch 5/10
# 6/6 [==============================] - 34s 6s/step - loss: 0.2204 - accuracy: 0.9322 - val_loss: 5.2378 - val_accuracy: 0.3778
# Epoch 6/10
# 6/6 [==============================] - 33s 5s/step - loss: 0.0568 - accuracy: 0.9774 - val_loss: 3.6264 - val_accuracy: 0.4444
# Epoch 7/10
# 6/6 [==============================] - 33s 6s/step - loss: 0.0460 - accuracy: 0.9831 - val_loss: 1.4730 - val_accuracy: 0.5556
# Epoch 8/10
# 6/6 [==============================] - 33s 5s/step - loss: 0.0454 - accuracy: 0.9887 - val_loss: 0.7289 - val_accuracy: 0.6889
# Epoch 9/10
# 6/6 [==============================] - 33s 5s/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.5146 - val_accuracy: 0.8667
# Epoch 10/10
# 6/6 [==============================] - 33s 5s/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 0.4913 - val_accuracy: 0.8889
# Train: 0.825, Test: 0.889
# Train Iteration: 1
# Epoch 1/10
# 6/6 [==============================] - 36s 6s/step - loss: 4.3183 - accuracy: 0.5763 - val_loss: 1.2566 - val_accuracy: 0.3778
# Epoch 2/10
# 6/6 [==============================] - 34s 6s/step - loss: 1.1858 - accuracy: 0.8362 - val_loss: 3.6628 - val_accuracy: 0.3778
# Epoch 3/10
# 6/6 [==============================] - 34s 6s/step - loss: 0.3985 - accuracy: 0.9040 - val_loss: 6.3277 - val_accuracy: 0.3778
# Epoch 4/10
# 6/6 [==============================] - 34s 6s/step - loss: 0.2140 - accuracy: 0.9379 - val_loss: 5.7091 - val_accuracy: 0.3778
# Epoch 5/10
# 6/6 [==============================] - 34s 6s/step - loss: 0.0896 - accuracy: 0.9718 - val_loss: 6.6850 - val_accuracy: 0.3778
# Epoch 6/10
# 6/6 [==============================] - 34s 6s/step - loss: 0.0760 - accuracy: 0.9605 - val_loss: 6.6219 - val_accuracy: 0.3778
# Epoch 7/10
# 6/6 [==============================] - 34s 6s/step - loss: 0.0301 - accuracy: 0.9831 - val_loss: 6.5134 - val_accuracy: 0.3778
# Epoch 8/10
# 6/6 [==============================] - 33s 6s/step - loss: 0.0364 - accuracy: 0.9831 - val_loss: 5.5224 - val_accuracy: 0.3778
# Epoch 9/10
# 6/6 [==============================] - 34s 6s/step - loss: 0.0638 - accuracy: 0.9887 - val_loss: 4.4630 - val_accuracy: 0.4444
# Epoch 10/10
# 6/6 [==============================] - 33s 6s/step - loss: 0.0443 - accuracy: 0.9774 - val_loss: 3.1538 - val_accuracy: 0.5333
# Train: 0.435, Test: 0.533
